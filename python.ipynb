# %%
n=int(input("enter a number: "))
if n % 7 == 0:
    print("divisible by 7")
else:
    print("not divisible by 7")
# Out:
# enter a number: 67
# not divisible by 7

# %%
ch=input("enter a character:")
if ch in "aeiou":
    print("vowel")
else:
    print("not a vowel")
# Out:
# enter a character:u
# vowel

# %%
age=int(input("enter age: "))
if age>=16:
    print("eligible for driving license")
else:
    print("not eligible")
# Out:
# enter age: 13
# not eligible

# %%
a=input("enter first string: ")
b=input("enter second string: ")
if a==b:
    print("strings are equal")
else:
    print("strings are not equal")
# Out:
# enter first string: ayisha
# enter second string: hameema
# strings are not equal

# %%
n=float(input("enter the purchase amount:"))
if n>5000:
    print("customer is eligible for discount")
else:
    print("not eligible for discount")
# Out:
# enter the purchase amount:7600
# customer is eligible for discount

# %%
n=int(input("enter a number: "))
if n>=10 and n<=100:
    print("number is between 10 and 100")
else:
    print("not between 10 and 100")
# Out:
# enter a number: 200
# not between 10 and 100

# %%
n=float(input("enter attendance percentage: "))
if n>=75:
    print("eligible to attend exam")
else:
    print("not eligible to attend exam")
# Out:
# enter attendance percentage: 78
# eligible to attend exam

# %%
ch=input("enter an alphabet: ")
if ch.isupper():
    print("uppercase")
else:
    print("lowercase")
# Out:
# enter an alphabet: W
# uppercase

# %%
n=int(input("enter number: "))
if n>=100 and n<=999:
    print("three digit number")
else:
    print("not a three digit number")
# Out:
# enter number: 45
# not a three digit number

# %%
data=float(input("enter amount of mobile data used in GB: "))
if data<2:
    print("low usage")
elif data<=5:
    print("moderate usage")
else:
    print("high usage")
# Out:
# enter amount of mobile data used in GB: 4
# moderate usage

# %%
mark=[54,67,32,87,98]
print(mark[0])
# Out:
# 54

# %%
a=[2,3,5,6,7,8]
a.append(5)
print(a)
# Out:
# [2, 3, 5, 6, 7, 8, 5]

# %%
numbers=(3,5,6,4,2)
print(numbers[3])
# Out:
# 4

# %%
numbers={23,56,90,90,23,45}
print(numbers)
# Out:
# {56, 90, 45, 23}

# %%
student={
    "name":"ayisha",
    "age":21,
    "place":"pkd"
}
print(student["name"])
# Out:
# ayisha

# %%
name="python"
print(name[0])
print(name[-1])
# Out:
# p
# n
